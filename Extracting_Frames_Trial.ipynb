# %%
# Program To Read video and Extract Frames 
import cv2
import os
# Function to extract frames 
def FrameCapture(pathList): #Path to video file 
    #path to parent directory
    parent_dir = "C:/Users/ganes/Python Programs/video_analysis"
    #path to create a new directory to strore file containing all the frames
    path_new = os.path.join(parent_dir, "inputFrames")
    os.mkdir(path_new)
    # Used as counter variable 
    count = 0
    for i in pathList:
        #directory_images=i[0:-3]
        # vidObj created
        vidObj = cv2.VideoCapture(i) 
        # checks whether frames were extracted 
        while True: 
            # vidObj object calls read 
            # function extract frames 
            success, image = vidObj.read() 
            if not success:
                break
            # Saves the frames with frame-count
            name = "frame" + str(count) +".jpg"
            image_path = path_new + "\\" + name
            cv2.imwrite(filename = image_path, img = image)
            #name = "frame" + str(count)
            #cv2.imwrite("%s.jpg" % name , image) 
            count += 1
# Calling the function  
pathList = ["input.mp4","input2.mp4"]
FrameCapture(pathList)

# %%
##Program for capturing video feed from camera and storing it into file
import cv2
import numpy as np
# Create a VideoCapture object
cap = cv2.VideoCapture(0)
# Check if camera opened successfully
if (cap.isOpened() == False): 
    print("Unable to read camera feed")
# Default resolutions of the frame are obtained.The default resolutions are system dependent.
# We convert the resolutions from float to integer.
#frame_width = int(cap.get(3))
#frame_height = int(cap.get(4))
# Define the codec and create VideoWriter object.The output is stored in 'outpy.avi' file.
out = cv2.VideoWriter('outpy.avi',cv2.VideoWriter_fourcc('M','J','P','G'), 10, (frame_width,frame_height))
count = 0
while(True):
    count = count+1
    ret, frame = cap.read()
    if ret == True: 
        # Write the frame into the file 'output.avi'
        out.write(frame)
        name= "frame" + str(count)
        cv2.imwrite("%s.jpg" % name , frame)
        # Display the resulting frame    
        cv2.imshow('frame',frame)
        # Press Q on keyboard to stop recording
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    # Break the loop
    else:
        break 
# When everything done, release the video capture and video write objects
cap.release()
out.release()
# Closes all the frames
cv2.destroyAllWindows()

# %%
import cv2
def FrameCapture(path): #Path to video file 
    # vidObj created  
    vidObj = cv2.VideoCapture(path) 
    # Used as counter variable 
    count = 0
    # checks whether frames were extracted 
    while True: 
        count=0
        # vidObj object calls read 
        # function extract frames 
        success, image = vidObj.read() 
        # Saves the frames with frame-count 
        cv2.imwrite("{}frame{}.jpg".format(path,count) , image) 
        count+=1
        if count==5:
            break
# Calling the function 
FrameCapture("input.mp4")

# %%
import cv2
import os 
def FrameCapture(path): #Path to video file 
    # vidObj created  
    directory_images = path[0:-4]
    vidObj = cv2.VideoCapture(path) 
    # Used as counter variable 
    count = 0
    # checks whether frames were extracted 
    while True: 
        count=0
        # vidObj object calls read 
        # function extract frames 
        success, image = vidObj.read() 
        # Saves the frames with frame-count 
        name=directory_images + "frame" + str(count)
        cv2.imwrite("%name.jpg" % count , image) 
        count+=1
        if count==5:
            break
# Calling the function 
FrameCapture("input.mp4")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-11-878a7bb2805d> in <module>
#      20             break
#      21 # Calling the function
# ---> 22 FrameCapture("input.mp4")
#
# <ipython-input-11-878a7bb2805d> in FrameCapture(path)
#      15         # Saves the frames with frame-count
#      16         name=directory_images + "frame" + str(count)
# ---> 17         cv2.imwrite("%d.jpg" % count , image)
#      18         count+=1
#      19         if count==5:
#
# error: OpenCV(4.3.0) C:\projects\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:738: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'

# %%
import os 
  
# Directory 
directory = "GeeksforGeeks"
  
# Parent Directory path 
parent_dir = "D:/Pycharm projects/"
  
# Path 
path = os.path.join(parent_dir, directory) 
  
# Create the directory 
# 'GeeksForGeeks' in 
# '/home / User / Documents' 
os.mkdir(path) 
print("Directory '% s' created" % directory) 
  
# Directory 
directory = "Geeks"
  
# Parent Directory path 
parent_dir = "D:/Pycharm projects"
  
# mode 
mode = 0o666
  
# Path 
path = os.path.join(parent_dir, directory) 
  
# Create the directory 
# 'GeeksForGeeks' in 
# '/home / User / Documents' 
# with mode 0o666 
os.mkdir(path, mode) 
print("Directory '% s' created" % directory)

# %%
# Program To Read video and Extract Frames in perticular directory
import cv2 
import os
# Function to extract frames 
def FrameCapture(path): #Path to video file 
    # vidObj created
    directory_images=path[0:-4]   #enter string location of path where actual video file name starts
    parent_dir = "C:/Users/ganes/Python Programs/video_analysis"
    path_new = os.path.join(parent_dir, directory_images)
    os.mkdir(path_new)
    vidObj = cv2.VideoCapture(path) 
    # Used as counter variable 
    count = 0
    # checks whether frames were extracted 
    while True: 
        # vidObj object calls read 
        # function extract frames 
        success, image = vidObj.read() 
        cv2.imshow("winsow",image)
        cv2.waitKey(0)
        if not success:
            break
        # Saves the frames with frame-count 
        name = "frame" + str(count) +".jpg"
        image_path = path_new + "\\" + name
        cv2.imwrite(filename = image_path, img = image) 
        count += 1
        
        if count>5:
            break
# Calling the function 
FrameCapture("input2.mp4")

# %%
import os
#os.mkdir("ip")
print(os.path.getsize("face.jpg"))
# Out:
# 95218
